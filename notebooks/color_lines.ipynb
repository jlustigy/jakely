# %%
# %matplotlib inline
import os
import numpy as np
import scipy as sp
import scipy.optimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import rc
#from astroML.plotting import setup_text_plots
#import pdb
#setup_text_plots(fontsize=25, usetex=True)

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
mpl.rcParams['font.size'] = 25.0
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import jakely

# %%
# Generate fake data for plotting
x1 = np.linspace(0.0, 10.0, 200)
y1 = np.sin(x1)
y2 = np.cos(x1)

# %%
# Create color grid
c1 = jakely.colorize(x1)[0]
c2 = jakely.colorize(y2, cmap="viridis")[0]

# %%
plt.scatter(x1,y1, c=c1, lw=0, s=30)
plt.scatter(x1,y2, c=c2, lw=0, s=30)
